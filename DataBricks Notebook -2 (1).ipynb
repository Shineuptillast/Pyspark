# %%
spark.conf.get('spark.app.name')
# Out:
# Out[1]: 'Databricks Shell'

# %%
df = spark.createDataFrame(data=[(1,'Mahaveer'),(2,'Naman')])

# %%
df.show()
# Out:
# +---+--------+
# | _1|      _2|
# +---+--------+
# |  1|Mahaveer|
# |  2|   Naman|
# +---+--------+

# %%
df.printSchema()
# Out:
# root
#  |-- _1: long (nullable = true)
#  |-- _2: string (nullable = true)

# %%
schema = ['Id','Name']

# %%
df1 = spark.createDataFrame(data=[(1,'Mahaveer'),(2,'Naman')],schema=schema)

# %%
df1.show()
# Out:
# +---+--------+
# | Id|    Name|
# +---+--------+
# |  1|Mahaveer|
# |  2|   Naman|
# +---+--------+

# %%
from pyspark.sql.types import *
Struct_schema=StructType([StructField('id',IntegerType(),False),StructField('name',StringType(),True)])

# %%
df2 = spark.createDataFrame(sc.parallelize([(1,'Shubham'),(2,'Keshav')]),schema=Struct_schema)

# %%
df2.show()
# Out:
# +---+-------+
# | id|   name|
# +---+-------+
# |  1|Shubham|
# |  2| Keshav|
# +---+-------+

# %%
df2.printSchema()
# Out:
# root
#  |-- id: integer (nullable = false)
#  |-- name: string (nullable = true)

# %%
data = [Row(id=1,name='Naman',age=25),Row(id=2,name='Keshav',age=26)]

# %%
df3 = spark.createDataFrame(data)

# %%
df3.show()
# Out:
# +---+------+---+
# | id|  name|age|
# +---+------+---+
# |  1| Naman| 25|
# |  2|Keshav| 26|
# +---+------+---+

# %%
df3.first()
# Out:
# Out[15]: Row(id=1, name='Naman', age=25)

# %%
df3.collect()
# Out:
# Out[16]: [Row(id=1, name='Naman', age=25), Row(id=2, name='Keshav', age=26)]

# %%
df4 = spark.createDataFrame([1,2,3,4,5],IntegerType())

# %%
df4.show()
# Out:
# +-----+
# |value|
# +-----+
# |    1|
# |    2|
# |    3|
# |    4|
# |    5|
# +-----+

# %%
df5= spark.createDataFrame(sc.parallelize([1,2,3,4,5]),IntegerType())

# %%
df5.show()
# Out:
# +-----+
# |value|
# +-----+
# |    1|
# |    2|
# |    3|
# |    4|
# |    5|
# +-----+

# %%
data = [
    (
        1, {'name':"Naman" , 'hobby':'Reading', 'status':'Learning Big Data'}),
        (2, {'name':'Tejal','hobby':'eating', 'status':'Teacher'}),
        (3, {'name':'Preeti','hobby':'Listening Music','status':'Working'}
    )
]

# %%
schema_nested=StructType([StructField('id',IntegerType()),StructField('detail',StructType([StructField('name',StringType()),StructField('hobby',StringType()),StructField('status',StringType())]))])

# %%
df6=spark.createDataFrame(data,schema=schema_nested)

# %%
df6.show()
# Out:
# +---+--------------------+
# | id|              detail|
# +---+--------------------+
# |  1|{Naman, Reading, ...|
# |  2|{Tejal, eating, T...|
# |  3|{Preeti, Listenin...|
# +---+--------------------+

# %%
df6.select('detail.hobby').show()
# Out:
# +---------------+
# |          hobby|
# +---------------+
# |        Reading|
# |         eating|
# |Listening Music|
# +---------------+

# %%
# Reading from external source
df7 = spark.read.load(path='dbfs:/FileStore/tables/AirQualityUCI.csv',format='csv',sep=';',inferschema=True)

# %%
df7.show(5)
# Out:
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |       _c0|     _c1|   _c2|        _c3|     _c4|     _c5|          _c6|    _c7|         _c8|    _c9|        _c10|       _c11|_c12|_c13|  _c14|_c15|_c16|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |      Date|    Time|CO(GT)|PT08.S1(CO)|NMHC(GT)|C6H6(GT)|PT08.S2(NMHC)|NOx(GT)|PT08.S3(NOx)|NO2(GT)|PT08.S4(NO2)|PT08.S5(O3)|   T|  RH|    AH|null|null|
# |10/03/2004|18.00.00|   2,6|       1360|     150|    11,9|         1046|    166|        1056|    113|        1692|       1268|13,6|48,9|0,7578|null|null|
# |10/03/2004|19.00.00|     2|       1292|     112|     9,4|          955|    103|        1174|     92|        1559|        972|13,3|47,7|0,7255|null|null|
# |10/03/2004|20.00.00|   2,2|       1402|      88|     9,0|          939|    131|        1140|    114|        1555|       1074|11,9|54,0|0,7502|null|null|
# |10/03/2004|21.00.00|   2,2|       1376|      80|     9,2|          948|    172|        1092|    122|        1584|       1203|11,0|60,0|0,7867|null|null|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# only showing top 5 rows

# %%
df7.schema
# Out:
# Out[28]: StructType([StructField('_c0', StringType(), True), StructField('_c1', StringType(), True), StructField('_c2', StringType(), True), StructField('_c3', StringType(), True), StructField('_c4', StringType(), True), StructField('_c5', StringType(), True), StructField('_c6', StringType(), True), StructField('_c7', StringType(), True), StructField('_c8', StringType(), True), StructField('_c9', StringType(), True), StructField('_c10', StringType(), True), StructField('_c11', StringType(), True), StructField('_c12', StringType(), True), StructField('_c13', StringType(), True), StructField('_c14', StringType(), True), StructField('_c15', StringType(), True), StructField('_c16', StringType(), True)])

# %%
df7.columns
# Out:
# Out[29]: ['_c0',
#  '_c1',
#  '_c2',
#  '_c3',
#  '_c4',
#  '_c5',
#  '_c6',
#  '_c7',
#  '_c8',
#  '_c9',
#  '_c10',
#  '_c11',
#  '_c12',
#  '_c13',
#  '_c14',
#  '_c15',
#  '_c16']

# %%
df7.dtypes
# Out:
# Out[30]: [('_c0', 'string'),
#  ('_c1', 'string'),
#  ('_c2', 'string'),
#  ('_c3', 'string'),
#  ('_c4', 'string'),
#  ('_c5', 'string'),
#  ('_c6', 'string'),
#  ('_c7', 'string'),
#  ('_c8', 'string'),
#  ('_c9', 'string'),
#  ('_c10', 'string'),
#  ('_c11', 'string'),
#  ('_c12', 'string'),
#  ('_c13', 'string'),
#  ('_c14', 'string'),
#  ('_c15', 'string'),
#  ('_c16', 'string')]

# %%
df7.show()
# Out:
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |       _c0|     _c1|   _c2|        _c3|     _c4|     _c5|          _c6|    _c7|         _c8|    _c9|        _c10|       _c11|_c12|_c13|  _c14|_c15|_c16|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |      Date|    Time|CO(GT)|PT08.S1(CO)|NMHC(GT)|C6H6(GT)|PT08.S2(NMHC)|NOx(GT)|PT08.S3(NOx)|NO2(GT)|PT08.S4(NO2)|PT08.S5(O3)|   T|  RH|    AH|null|null|
# |10/03/2004|18.00.00|   2,6|       1360|     150|    11,9|         1046|    166|        1056|    113|        1692|       1268|13,6|48,9|0,7578|null|null|
# |10/03/2004|19.00.00|     2|       1292|     112|     9,4|          955|    103|        1174|     92|        1559|        972|13,3|47,7|0,7255|null|null|
# |10/03/2004|20.00.00|   2,2|       1402|      88|     9,0|          939|    131|        1140|    114|        1555|       1074|11,9|54,0|0,7502|null|null|
# |10/03/2004|21.00.00|   2,2|       1376|      80|     9,2|          948|    172|        1092|    122|        1584|       1203|11,0|60,0|0,7867|null|null|
# |10/03/2004|22.00.00|   1,6|       1272|      51|     6,5|          836|    131|        1205|    116|        1490|       1110|11,2|59,6|0,7888|null|null|
# |10/03/2004|23.00.00|   1,2|       1197|      38|     4,7|          750|     89|        1337|     96|        1393|        949|11,2|59,2|0,7848|null|null|
# |11/03/2004|00.00.00|   1,2|       1185|      31|     3,6|          690|     62|        1462|     77|        1333|        733|11,3|56,8|0,7603|null|null|
# |11/03/2004|01.00.00|     1|       1136|      31|     3,3|          672|     62|        1453|     76|        1333|        730|10,7|60,0|0,7702|null|null|
# |11/03/2004|02.00.00|   0,9|       1094|      24|     2,3|          609|     45|        1579|     60|        1276|        620|10,7|59,7|0,7648|null|null|
# |11/03/2004|03.00.00|   0,6|       1010|      19|     1,7|          561|   -200|        1705|   -200|        1235|        501|10,3|60,2|0,7517|null|null|
# |11/03/2004|04.00.00|  -200|       1011|      14|     1,3|          527|     21|        1818|     34|        1197|        445|10,1|60,5|0,7465|null|null|
# |11/03/2004|05.00.00|   0,7|       1066|       8|     1,1|          512|     16|        1918|     28|        1182|        422|11,0|56,2|0,7366|null|null|
# |11/03/2004|06.00.00|   0,7|       1052|      16|     1,6|          553|     34|        1738|     48|        1221|        472|10,5|58,1|0,7353|null|null|
# |11/03/2004|07.00.00|   1,1|       1144|      29|     3,2|          667|     98|        1490|     82|        1339|        730|10,2|59,6|0,7417|null|null|
# |11/03/2004|08.00.00|     2|       1333|      64|     8,0|          900|    174|        1136|    112|        1517|       1102|10,8|57,4|0,7408|null|null|
# |11/03/2004|09.00.00|   2,2|       1351|      87|     9,5|          960|    129|        1079|    101|        1583|       1028|10,5|60,6|0,7691|null|null|
# |11/03/2004|10.00.00|   1,7|       1233|      77|     6,3|          827|    112|        1218|     98|        1446|        860|10,8|58,4|0,7552|null|null|
# |11/03/2004|11.00.00|   1,5|       1179|      43|     5,0|          762|     95|        1328|     92|        1362|        671|10,5|57,9|0,7352|null|null|
# |11/03/2004|12.00.00|   1,6|       1236|      61|     5,2|          774|    104|        1301|     95|        1401|        664| 9,5|66,8|0,7951|null|null|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# only showing top 20 rows

# %%
df8 = spark.read.format('csv').option('header',True).option('inferschema',True).load('dbfs:/FileStore/tables/AirQualityUCI.csv',sep=';')

# %%
df8.show()
# Out:
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |      Date|    Time|CO(GT)|PT08.S1(CO)|NMHC(GT)|C6H6(GT)|PT08.S2(NMHC)|NOx(GT)|PT08.S3(NOx)|NO2(GT)|PT08.S4(NO2)|PT08.S5(O3)|   T|  RH|    AH|_c15|_c16|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |2004-03-10|18.00.00|   2,6|       1360|     150|    11,9|         1046|    166|        1056|    113|        1692|       1268|13,6|48,9|0,7578|null|null|
# |2004-03-10|19.00.00|     2|       1292|     112|     9,4|          955|    103|        1174|     92|        1559|        972|13,3|47,7|0,7255|null|null|
# |2004-03-10|20.00.00|   2,2|       1402|      88|     9,0|          939|    131|        1140|    114|        1555|       1074|11,9|54,0|0,7502|null|null|
# |2004-03-10|21.00.00|   2,2|       1376|      80|     9,2|          948|    172|        1092|    122|        1584|       1203|11,0|60,0|0,7867|null|null|
# |2004-03-10|22.00.00|   1,6|       1272|      51|     6,5|          836|    131|        1205|    116|        1490|       1110|11,2|59,6|0,7888|null|null|
# |2004-03-10|23.00.00|   1,2|       1197|      38|     4,7|          750|     89|        1337|     96|        1393|        949|11,2|59,2|0,7848|null|null|
# |2004-03-11|00.00.00|   1,2|       1185|      31|     3,6|          690|     62|        1462|     77|        1333|        733|11,3|56,8|0,7603|null|null|
# |2004-03-11|01.00.00|     1|       1136|      31|     3,3|          672|     62|        1453|     76|        1333|        730|10,7|60,0|0,7702|null|null|
# |2004-03-11|02.00.00|   0,9|       1094|      24|     2,3|          609|     45|        1579|     60|        1276|        620|10,7|59,7|0,7648|null|null|
# |2004-03-11|03.00.00|   0,6|       1010|      19|     1,7|          561|   -200|        1705|   -200|        1235|        501|10,3|60,2|0,7517|null|null|
# |2004-03-11|04.00.00|  -200|       1011|      14|     1,3|          527|     21|        1818|     34|        1197|        445|10,1|60,5|0,7465|null|null|
# |2004-03-11|05.00.00|   0,7|       1066|       8|     1,1|          512|     16|        1918|     28|        1182|        422|11,0|56,2|0,7366|null|null|
# |2004-03-11|06.00.00|   0,7|       1052|      16|     1,6|          553|     34|        1738|     48|        1221|        472|10,5|58,1|0,7353|null|null|
# |2004-03-11|07.00.00|   1,1|       1144|      29|     3,2|          667|     98|        1490|     82|        1339|        730|10,2|59,6|0,7417|null|null|
# |2004-03-11|08.00.00|     2|       1333|      64|     8,0|          900|    174|        1136|    112|        1517|       1102|10,8|57,4|0,7408|null|null|
# |2004-03-11|09.00.00|   2,2|       1351|      87|     9,5|          960|    129|        1079|    101|        1583|       1028|10,5|60,6|0,7691|null|null|
# |2004-03-11|10.00.00|   1,7|       1233|      77|     6,3|          827|    112|        1218|     98|        1446|        860|10,8|58,4|0,7552|null|null|
# |2004-03-11|11.00.00|   1,5|       1179|      43|     5,0|          762|     95|        1328|     92|        1362|        671|10,5|57,9|0,7352|null|null|
# |2004-03-11|12.00.00|   1,6|       1236|      61|     5,2|          774|    104|        1301|     95|        1401|        664| 9,5|66,8|0,7951|null|null|
# |2004-03-11|13.00.00|   1,9|       1286|      63|     7,3|          869|    146|        1162|    112|        1537|        799| 8,3|76,4|0,8393|null|null|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# only showing top 20 rows

# %%
df9= spark.read.csv('dbfs:/FileStore/tables/AirQualityUCI.csv',header=True,sep=';')

# %%
df9.show()
# Out:
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |      Date|    Time|CO(GT)|PT08.S1(CO)|NMHC(GT)|C6H6(GT)|PT08.S2(NMHC)|NOx(GT)|PT08.S3(NOx)|NO2(GT)|PT08.S4(NO2)|PT08.S5(O3)|   T|  RH|    AH|_c15|_c16|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# |10/03/2004|18.00.00|   2,6|       1360|     150|    11,9|         1046|    166|        1056|    113|        1692|       1268|13,6|48,9|0,7578|null|null|
# |10/03/2004|19.00.00|     2|       1292|     112|     9,4|          955|    103|        1174|     92|        1559|        972|13,3|47,7|0,7255|null|null|
# |10/03/2004|20.00.00|   2,2|       1402|      88|     9,0|          939|    131|        1140|    114|        1555|       1074|11,9|54,0|0,7502|null|null|
# |10/03/2004|21.00.00|   2,2|       1376|      80|     9,2|          948|    172|        1092|    122|        1584|       1203|11,0|60,0|0,7867|null|null|
# |10/03/2004|22.00.00|   1,6|       1272|      51|     6,5|          836|    131|        1205|    116|        1490|       1110|11,2|59,6|0,7888|null|null|
# |10/03/2004|23.00.00|   1,2|       1197|      38|     4,7|          750|     89|        1337|     96|        1393|        949|11,2|59,2|0,7848|null|null|
# |11/03/2004|00.00.00|   1,2|       1185|      31|     3,6|          690|     62|        1462|     77|        1333|        733|11,3|56,8|0,7603|null|null|
# |11/03/2004|01.00.00|     1|       1136|      31|     3,3|          672|     62|        1453|     76|        1333|        730|10,7|60,0|0,7702|null|null|
# |11/03/2004|02.00.00|   0,9|       1094|      24|     2,3|          609|     45|        1579|     60|        1276|        620|10,7|59,7|0,7648|null|null|
# |11/03/2004|03.00.00|   0,6|       1010|      19|     1,7|          561|   -200|        1705|   -200|        1235|        501|10,3|60,2|0,7517|null|null|
# |11/03/2004|04.00.00|  -200|       1011|      14|     1,3|          527|     21|        1818|     34|        1197|        445|10,1|60,5|0,7465|null|null|
# |11/03/2004|05.00.00|   0,7|       1066|       8|     1,1|          512|     16|        1918|     28|        1182|        422|11,0|56,2|0,7366|null|null|
# |11/03/2004|06.00.00|   0,7|       1052|      16|     1,6|          553|     34|        1738|     48|        1221|        472|10,5|58,1|0,7353|null|null|
# |11/03/2004|07.00.00|   1,1|       1144|      29|     3,2|          667|     98|        1490|     82|        1339|        730|10,2|59,6|0,7417|null|null|
# |11/03/2004|08.00.00|     2|       1333|      64|     8,0|          900|    174|        1136|    112|        1517|       1102|10,8|57,4|0,7408|null|null|
# |11/03/2004|09.00.00|   2,2|       1351|      87|     9,5|          960|    129|        1079|    101|        1583|       1028|10,5|60,6|0,7691|null|null|
# |11/03/2004|10.00.00|   1,7|       1233|      77|     6,3|          827|    112|        1218|     98|        1446|        860|10,8|58,4|0,7552|null|null|
# |11/03/2004|11.00.00|   1,5|       1179|      43|     5,0|          762|     95|        1328|     92|        1362|        671|10,5|57,9|0,7352|null|null|
# |11/03/2004|12.00.00|   1,6|       1236|      61|     5,2|          774|    104|        1301|     95|        1401|        664| 9,5|66,8|0,7951|null|null|
# |11/03/2004|13.00.00|   1,9|       1286|      63|     7,3|          869|    146|        1162|    112|        1537|        799| 8,3|76,4|0,8393|null|null|
# +----------+--------+------+-----------+--------+--------+-------------+-------+------------+-------+------------+-----------+----+----+------+----+----+
# only showing top 20 rows

# %%
df9.schema
# Out:
# Out[36]: StructType([StructField('Date', StringType(), True), StructField('Time', StringType(), True), StructField('CO(GT)', StringType(), True), StructField('PT08.S1(CO)', StringType(), True), StructField('NMHC(GT)', StringType(), True), StructField('C6H6(GT)', StringType(), True), StructField('PT08.S2(NMHC)', StringType(), True), StructField('NOx(GT)', StringType(), True), StructField('PT08.S3(NOx)', StringType(), True), StructField('NO2(GT)', StringType(), True), StructField('PT08.S4(NO2)', StringType(), True), StructField('PT08.S5(O3)', StringType(), True), StructField('T', StringType(), True), StructField('RH', StringType(), True), StructField('AH', StringType(), True), StructField('_c15', StringType(), True), StructField('_c16', StringType(), True)])

# %%
# loading multiple files 
df10 = spark.read.csv('dbfs:/FileStore/data/',header=True)

# %%
df10.show()
# Out:
# +-------+-------+---+-----------+
# |   name|  class|age|      hobby|
# +-------+-------+---+-----------+
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# +-------+-------+---+-----------+

# %%
# Reading files from multiple locations
df11 = spark.read.option('header',True).schema(schema_).csv(path=['dbfs:/FileStore/data_trial/','dbfs:/FileStore/data/'])

# %%
df11.show()
# Out:
# +-------+-------+---+-----------+
# |   name|  class|age|      hobby|
# +-------+-------+---+-----------+
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# +-------+-------+---+-----------+

# %%
df11.show()
df11.printSchema()
# Out:
# +-------+-------+---+-----------+
# |   name|  class|age|      hobby|
# +-------+-------+---+-----------+
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# +-------+-------+---+-----------+
#
# root
#  |-- name: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- hobby: string (nullable = true)

# %%
schema_=StructType([StructField('name',StringType()),StructField('class',StringType()),StructField('age',StringType()),StructField('hobby',StringType())])

# %%
df11.write.option('header',True).csv('dbfs:/FileStore/folder1/')
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-450662794109507>:1
# ----> 1 df11.write.option('header',True).csv('dbfs:/FileStore/folder1/')
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:1798, in DataFrameWriter.csv(self, path, mode, compression, sep, quote, escape, header, nullValue, escapeQuotes, quoteAll, dateFormat, timestampFormat, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, charToEscapeQuoteEscaping, encoding, emptyValue, lineSep)
#    1779 self.mode(mode)
#    1780 self._set_opts(
#    1781     compression=compression,
#    1782     sep=sep,
#    (...)
#    1796     lineSep=lineSep,
#    1797 )
# -> 1798 self._jwrite.csv(path)
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: Path dbfs:/FileStore/folder1 already exists.

# %%
df11.write.mode('overwrite').option('header',True).csv('dbfs:/FileStore/folder1/')

# %%
# saving files in parquet format
df11.write.mode('overwrite').format('parquet').save('dbfs:/FileStore/folder6/')

# %%
# saving files in text format
df11.write.mode('overwrite').format('orc').save('dbfs:/FileStore/folder3/')

# %%
# saving files in avro
df11.write.mode('overwrite').format('avro').save('dbfs:/FileStore/folder4/')

# %%
df11.write.mode('overwrite').format('json').save('dbfs:/FileStore/folder5/')

# %%
df11.write.mode('overwrite').saveAsTable('df11_table')

# %%
spark.catalog.listDatabases()
# Out:
# Out[53]: [Database(name='default', catalog='spark_catalog', description='Default Hive database', locationUri='dbfs:/user/hive/warehouse')]

# %%
spark.catalog.listTables()
# Out:
# Out[54]: [Table(name='df11_table', catalog='spark_catalog', namespace=['default'], description=None, tableType='MANAGED', isTemporary=False)]

# %%
# Reading Json Files
df12 = spark.read.json('dbfs:/FileStore/folder5/part-00002-tid-8837628280442544222-7915c449-6bce-4733-b1ac-61bba5c8f730-197-1-c000.json')

# %%
df12.show()
# Out:
# +---+-------+-----------+-------+
# |age|  class|      hobby|   name|
# +---+-------+-----------+-------+
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# +---+-------+-----------+-------+

# %%
# 2nd way of reading json files
df12 = spark.read.format('json').load('dbfs:/FileStore/folder5/part-00002-tid-8837628280442544222-7915c449-6bce-4733-b1ac-61bba5c8f730-197-1-c000.json')

# %%
df12.show()
# Out:
# +---+-------+-----------+-------+
# |age|  class|      hobby|   name|
# +---+-------+-----------+-------+
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# +---+-------+-----------+-------+

# %%
df12.printSchema()
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- hobby: string (nullable = true)
#  |-- name: string (nullable = true)

# %%
df13 = spark.read.json(path="dbfs:/FileStore/folder5/*.json")

# %%
df13.show()
# Out:
# +---+-------+-----------+-------+
# |age|  class|      hobby|   name|
# +---+-------+-----------+-------+
# | 20|college|    Reading|  naman|
# | 25|Teacher|     Eating|  Tejal|
# | 20|college|    Reading|  naman|
# | 25|Teacher|     Eating|  Tejal|
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# | 16|     12|     gaming|   sidd|
# | 20|college|watching-Tv|nirjara|
# +---+-------+-----------+-------+

# %%
# Reading parquet File 
df14 = spark.read.format('parquet').load("dbfs:/FileStore/folder6/*.parquet")

# %%
df14.show()
# Out:
# +-------+-------+---+-----------+
# |   name|  class|age|      hobby|
# +-------+-------+---+-----------+
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |  naman|college| 20|    Reading|
# |  Tejal|Teacher| 25|     Eating|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# |   sidd|     12| 16|     gaming|
# |nirjara|college| 20|watching-Tv|
# +-------+-------+---+-----------+

# %%
df14.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- hobby: string (nullable = true)

# %%
# Adding new columns to the dataframe

# %%
df16=df14.withColumn('skills',lit('python'))

# %%
df16.show()
# Out:
# +-------+-------+---+-----------+------+
# |   name|  class|age|      hobby|skills|
# +-------+-------+---+-----------+------+
# |  naman|college| 20|    Reading|python|
# |  Tejal|Teacher| 25|     Eating|python|
# |  naman|college| 20|    Reading|python|
# |  Tejal|Teacher| 25|     Eating|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# +-------+-------+---+-----------+------+

# %%
#Changing the Type of column in dataframe

# %%
df17= df16.withColumn('age', col('age').cast('int'))

# %%
df17.show()
# Out:
# +-------+-------+---+-----------+------+
# |   name|  class|age|      hobby|skills|
# +-------+-------+---+-----------+------+
# |  naman|college| 20|    Reading|python|
# |  Tejal|Teacher| 25|     Eating|python|
# |  naman|college| 20|    Reading|python|
# |  Tejal|Teacher| 25|     Eating|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# |   sidd|     12| 16|     gaming|python|
# |nirjara|college| 20|watching-Tv|python|
# +-------+-------+---+-----------+------+

# %%
df17.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- hobby: string (nullable = true)
#  |-- skills: string (nullable = false)
